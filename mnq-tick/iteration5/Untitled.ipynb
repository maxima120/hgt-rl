# %%
import pandas as pd
SRC_FILE='stage-5/pred_raw_mnq-vol2-4STR-9-12am-RSX-v1_3s.pqt'
df = pd.read_parquet(SRC_FILE)

# %%
print(df.head())
# Out:
#    bar_index           timestamp  is_target         p     p_cal
# 0    2198363 2024-06-03 09:00:30      False  0.077565  0.074463
# 1    2198364 2024-06-03 09:00:33      False  0.012628  0.015744
# 2    2198365 2024-06-03 09:00:36      False  0.024950  0.024988
# 3    2198366 2024-06-03 09:00:39      False  0.004847  0.004447
# 4    2198367 2024-06-03 09:00:42      False  0.019579  0.019580
